# %% [markdown]
# <a href="https://colab.research.google.com/github/eltondeoliveirasilva/Interpretabilidade/blob/main/Shap_Pratica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install shap

# %%
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import numpy as np
import shap

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
x,y = shap.datasets.imdb()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

vectorizer = TfidfVectorizer(min_df=10)

x_train = vectorizer.fit_transform(x_train).toarray()
x_test = vectorizer.transform(corpus_test).toarray()

# %%
model = sklearn.linear_model.LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
explainer = shap.Explainer(model, x_train, feature_names=vectorizer.get_feature_names_out())
shap_values = explainer(x_test)

# %%
shap.plots.beeswarm(shap_values)
